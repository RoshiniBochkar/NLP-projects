# %% [markdown]
# <a href="https://colab.research.google.com/github/Bayapu-Reddy/Nlp/blob/main/text_extraction_from_pdf_%2Curl%2Cword%2Chtml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyPDF2==3.0.1
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.4 MB/s eta 0:00:00
# ...

# %%
import PyPDF2
from PyPDF2 import PdfReader

# %%
pdf=open("/content/NLP lab1.1.pdf","rb")

pdf_reader=PyPDF2.PdfReader(pdf)
print("number of pages: ",len(pdf_reader.pages))
page=pdf_reader.pages[0]
print(page.extract_text())

pdf.close()
# Out:
# number of pages:  18
# 17opnmio8
# F ebruary 9, 2025
# [9]: defmytokenizer (corpus):
# newcorpus =corpus+"$"
# words=[]
# tmp=""
# fori inrange(len(sentence)):
# ifnewcorpus[i] in["","$",".","\n"]:
# iflen(tmp)>0:
# words.append(tmp)
# tmp=""
# else:
# tmp=tmp+sentence[i]
# returnwords
# deftext_filter (tokens):
# #to remove punctuation from text
# punc='''!()-[] {};:'"\,<>./?@#$ %^&*_~￿'''
# clean_tokens =[w.strip(punc) forw intokens]
# # remove numbers from text
# clean_tokens =[tx fortx inclean_tokens if nottx.isdigit()]
# # remove numbers from alphanemeric words
# digits='''0123456789 '''
# clean_tokens =[w.strip(digits) forwinclean_tokens]
# returnclean_tokens
# stop_words =["i","are","we","is","to","and","will","shall","should","they","him","he","her"]
# defremove_stopwords (tokens):
# new_tokens =[w forw intokens ifw not instop_words]
# returnnew_tokens
# import re
# defmy_stemmer (tokens):
# stems=[
# 1

# %%
import PyPDF2,urllib,nltk
from io import BytesIO
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
wFile=urllib.request.urlopen("http://www.udri.org/pdf/02%20working%20paper%201.pdf")

pdfreader=PyPDF2.PdfReader(BytesIO(wFile.read()))

# %%
nltk.download('punkt_tab')
pageObj=pdfreader.pages[2]
page2=pageObj.extract_text()
punctuations=['(',')',':',';','[',']',',',',','...','.']
tokens = word_tokenize(page2)
stop_words=stopwords.words("english")
keywords=[word for word in tokens if not word in stop_words and not word in punctuations]
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
keywords
# Out:
# ['Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐2034',
#  'Table',
#  'Contents',
#  'The',
#  'Consultant',
#  'wishes',
#  'thank',
#  'following',
#  'individuals',
#  'Municipal',
#  'Corporation',
#  'Greater',
#  'Mumbai',
#  'invaluable',
#  'support',
#  'insights',
#  'contributions',
#  'towards',
#  '‘',
#  'Working',
#  'Paper',
#  '1',
#  '–',
#  'Preparation',
#  'Base',
#  'Map',
#  '’',
#  'preparation',
#  'Development',
#  'Plan',
#  'Greater',
#  'Mumbai',
#  '2014‐34',
#  '.............................................................................................................................',
#  '..............',
#  '3',
#  'Our',
#  'gratitude',
#  'following',
#  'experts',
#  'invaluable',
#  'insights',
#  'support',
#  '............................',
#  '3',
#  'We',
#  'wish',
#  'especially',
#  'thank',
#  'MCGM',
#  'officers',
#  'Mr.',
#  'Jagdish',
#  'Talreja',
#  'Mr.',
#  'Dinesh',
#  'Naik',
#  'Mr.',
#  'Hiren',
# ...

# %%
name_list=list()
check=["Mr.",'Mrs.','Ms.']
for idx,token in enumerate(tokens):
  if token.startswith(tuple(check)) and idx < (len(tokens)-1):
    name=token+tokens[idx+1]+' '+tokens[idx+2]
    name_list.append(name)

print(name_list)
# Out:
# ['Mr.Jagdish Talreja', 'Mr.Dinesh Naik', 'Mr.Hiren Daftardar', 'Ms.Anita Naik', 'Mr.Prasad Gharat']

# %%
wFile.close()

# %%
# !pip install Python_docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import docx

# %%
doc=open("/content/IOT HOLIDAY.docx","rb")
document=docx.Document(doc)

# %%
docu=""
for para in document.paragraphs:
  docu +=para.text
print(docu)
# Out:
# Write a Embedded C Program to Create a Weather Reporting System that provides real- time environmental data to users.     Code: #include <DHT.h>#include <Wire.h>#include <LiquidCrystal_I2C.h>#define DHTPIN 2#define DHTTYPE DHT11DHT dht(DHTPIN, DHTTYPE);LiquidCrystal_I2C lcd(0x27, 16, 2);void setup() {  dht.begin();  lcd.init();  lcd.backlight();  lcd.setCursor(0, 0);  lcd.print("Weather Report");}void loop() {  float temp = dht.readTemperature();  float hum = dht.readHumidity();  if (isnan(temp) || isnan(hum)) {    lcd.setCursor(0, 1);    lcd.print("Error Reading");    return;  }  lcd.setCursor(0, 1);  lcd.print("Temp: ");  lcd.print(temp);  lcd.print("C ");  lcd.print("Hum: ");  lcd.print(hum);  lcd.print("%");  delay(2000);}OP:Write a Embedded C Program to Create a Home Automation System that simplifies daily routines (Any 2 Devices) by controlling devices remotely.     Code:    #define LED1 2#define LED2 3void setup() {  // Initialize the LEDs as outputs  pinMode(LED1, OUTPUT);  p
# ...

# %%
for i in range(len(document.paragraphs)):
  print("the content of the paragon:"+str(i)+" is"+document.paragraphs[i].text+"\n")
# Out:
# the content of the paragon:0 isWrite a Embedded C Program to Create a Weather Reporting System that provides real- time environmental data to users.
#
# the content of the paragon:1 is
#
# the content of the paragon:2 is     Code:
#
# the content of the paragon:3 is #include <DHT.h>
#
# the content of the paragon:4 is#include <Wire.h>
#
# the content of the paragon:5 is#include <LiquidCrystal_I2C.h>
#
# the content of the paragon:6 is
#
# the content of the paragon:7 is#define DHTPIN 2
#
# the content of the paragon:8 is#define DHTTYPE DHT11
#
# the content of the paragon:9 is
#
# the content of the paragon:10 isDHT dht(DHTPIN, DHTTYPE);
#
# the content of the paragon:11 isLiquidCrystal_I2C lcd(0x27, 16, 2);
#
# the content of the paragon:12 is
#
# the content of the paragon:13 isvoid setup() {
#
# the content of the paragon:14 is  dht.begin();
#
# the content of the paragon:15 is  lcd.init();
#
# the content of the paragon:16 is  lcd.backlight();
#
# ...

# %%
# !pip install bs4

# %%
import urllib.request as urllib2
from bs4 import BeautifulSoup

# %%
response=urllib2.urlopen('https://en.wikipedia.org/wiki/About_Fate')
html_doc=response.read()

# %%
soup=BeautifulSoup(html_doc,'html.parser')
strhtm=soup.prettify()
print(strhtm[:5000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    About Fate - Wikipedia
#   </title>
#   <script>
# ...
